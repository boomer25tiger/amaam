# %% [markdown]
# # AMAAM — Exploratory Analysis
#
# Scratch notebook for ad-hoc data exploration, factor visualisation, and
# interim sanity checks during development. Nothing here feeds production code.

# %%
import sys
sys.path.insert(0, '..')
